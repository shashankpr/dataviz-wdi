# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

# %matplotlib inline
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (7.0, 4.5)
plt.rcParams['font.size'] = 9
#plt.rcParams['figure.titlesize'] = 10
plt.rcParams['axes.titlesize'] = 10
plt.rcParams['axes.labelsize'] = 9
plt.rcParams['legend.fontsize'] = 8
plt.rcParams['xtick.labelsize'] = 8
plt.rcParams['ytick.labelsize'] = 8
plt.rcParams['axes.formatter.useoffset'] = False
plt.rcParams['xtick.major.size'] = 0
plt.rcParams['ytick.major.size'] = 0

# %%
raw_data = pd.read_csv("data/Indicators.csv")

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5656458 entries, 0 to 5656457
# Data columns (total 6 columns):
# CountryName      object
# CountryCode      object
# IndicatorName    object
# IndicatorCode    object
# Year             int64
# Value            float64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 302.1+ MB

# %%
chosen_indicators = ['IP.JRN.ARTC.SC', 'SP.DYN.LE00.IN' ]
df_indicators = raw_data[raw_data.IndicatorCode.isin(chosen_indicators)]

# %%
df_indicators.head()
# Out:
#                                        CountryName CountryCode  \
# 1093546    East Asia & Pacific (all income levels)         EAS
# 1094007      East Asia & Pacific (developing only)         EAP
# 1094325                                  Euro area         EMU
# 1094606  Europe & Central Asia (all income levels)         ECS
# 1095276                             European Union         EUU
#
#                                      IndicatorName   IndicatorCode  Year  \
# 1093546  Scientific and technical journal articles  IP.JRN.ARTC.SC  1981
# 1094007  Scientific and technical journal articles  IP.JRN.ARTC.SC  1981
# 1094325  Scientific and technical journal articles  IP.JRN.ARTC.SC  1981
# 1094606  Scientific and technical journal articles  IP.JRN.ARTC.SC  1981
# 1095276  Scientific and technical journal articles  IP.JRN.ARTC.SC  1981
#
#           Value
# 1093546   36706
# 1094007    1100
# 1094325   70894
# 1094606  124958
# 1095276  117952

# %%
df_ip = raw_data[raw_data.IndicatorCode == 'IP.JRN.ARTC.SC']
df_ip_1990= df_ip[df_ip.Year > 1990]

# %%
newDict = {}
newDict["Year"] = df_ip_1990["Year"]
newDict['IP.JRN.ARTC.SC'] = df_ip_1990["Value"]
newDict["CountryName"] = df_ip_1990["CountryName"]
newDict["CountryCode"] = df_ip_1990["CountryCode"]

# %%
pd.DataFrame(newDict)
# Out:
#         CountryCode                                     CountryName  \
# 1998367         ARB                                      Arab World
# 1998715         CSS                          Caribbean small states
# 1999033         CEB                  Central Europe and the Baltics
# 1999431         EAS         East Asia & Pacific (all income levels)
# 2000029         EAP           East Asia & Pacific (developing only)
# 2000477         EMU                                       Euro area
# 2000866         ECS       Europe & Central Asia (all income levels)
# 2001408         ECA         Europe & Central Asia (developing only)
# 2001848         EUU                                  European Union
# 2002208         FCS        Fragile and conflict affected situations
# 2002578         HPC          Heavily indebted poor countries (HIPC)
# 2003007         HIC                                     High income
# 2003793         OEC                               High income: OECD
# ...

# %%
df_ip_n = raw_data[raw_data.IndicatorCode == 'SP.DYN.LE00.IN']
df_ip_n_1990 = df_ip_n[df_ip_n.Year > 1990]
df_ip_n_1990.head()
# Out:
#                                      CountryName CountryCode  \
# 1998219                               Arab World         ARB
# 1998573                   Caribbean small states         CSS
# 1998924           Central Europe and the Baltics         CEB
# 1999284  East Asia & Pacific (all income levels)         EAS
# 1999763    East Asia & Pacific (developing only)         EAP
#
#                                    IndicatorName   IndicatorCode  Year  \
# 1998219  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  1991
# 1998573  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  1991
# 1998924  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  1991
# 1999284  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  1991
# 1999763  Life expectancy at birth, total (years)  SP.DYN.LE00.IN  1991
#
#              Value
# 1998219  65.000099
# 1998573  69.040605
# 1998924  70.572608
# 1999284  69.423315
# 1999763  68.420665

# %%
newDict['SP.DYN.LE00.IN'] = df_ip_n_1990["Value"]
pd.DataFrame(newDict)
# Out:
#         CountryCode                                    CountryName  \
# 1998219         NaN                                            NaN
# 1998367         ARB                                     Arab World
# 1998573         NaN                                            NaN
# 1998715         CSS                         Caribbean small states
# 1998924         NaN                                            NaN
# 1999033         CEB                 Central Europe and the Baltics
# 1999284         NaN                                            NaN
# 1999431         EAS        East Asia & Pacific (all income levels)
# 1999763         NaN                                            NaN
# 2000029         EAP          East Asia & Pacific (developing only)
# 2000323         NaN                                            NaN
# 2000477         EMU                                      Euro area
# 2000727         NaN                                            NaN
# ...

# %%
year = 1989
raw_data_1990 = raw_data[raw_data.Year > year]
raw_data_1990.head()
# Out:
#         CountryName CountryCode  \
# 1880402  Arab World         ARB
# 1880403  Arab World         ARB
# 1880404  Arab World         ARB
# 1880405  Arab World         ARB
# 1880406  Arab World         ARB
#
#                                              IndicatorName      IndicatorCode  \
# 1880402            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 1880403  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 1880404  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 1880405         Access to non-solid fuel (% of population)     EG.NSF.ACCS.ZS
# 1880406  Adjusted net enrolment rate, primary, both sex...        SE.PRM.TENR
#
#          Year      Value
# 1880402  1990  75.447507
# 1880403  1990  58.680636
# 1880404  1990  91.842354
# 1880405  1990  74.223510
# 1880406  1990  72.104721

# %%
test = raw_data_1990.pivot_table('Value', ['Year','CountryName', 'CountryCode'], 'IndicatorCode'  )

# %%
test
# Out:
# IndicatorCode                              AG.AGR.TRAC.NO  AG.CON.FERT.PT.ZS  \
# Year CountryName              CountryCode
# 1990 Afghanistan              AFG                     120                NaN
#      Albania                  ALB                   12300                NaN
#      Algeria                  DZA                   91426                NaN
#      American Samoa           ASM                      11                NaN
#      Andorra                  ADO                     NaN                NaN
#      Angola                   AGO                     NaN                NaN
#      Antigua and Barbuda      ATG                     NaN                NaN
#      Arab World               ARB                  383795                NaN
#      Argentina                ARG                  264500                NaN
#      Armenia                  ARM                     NaN                NaN
#      Aruba                    ABW                     NaN                NaN
# ...

# %%
test.to_csv("test.csv")

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 6421 entries, (1990, Afghanistan, AFG) to (2015, Zimbabwe, ZWE)
# Columns: 1344 entries, 2005 PPP conversion factor, GDP (LCU per international $) to Youth literacy rate, population 15-24 years, male (%)
# dtypes: float64(1344)
# memory usage: 65.9+ MB

# %%
"Equity" in raw_data.IndicatorName
# Out:
# False

# %%
countryData = pd.read_csv("data/Country.csv")

# %%
countryData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 247 entries, 0 to 246
# Data columns (total 31 columns):
# CountryCode                                   247 non-null object
# ShortName                                     247 non-null object
# TableName                                     247 non-null object
# LongName                                      247 non-null object
# Alpha2Code                                    244 non-null object
# CurrencyUnit                                  214 non-null object
# SpecialNotes                                  164 non-null object
# Region                                        214 non-null object
# IncomeGroup                                   214 non-null object
# Wb2Code                                       246 non-null object
# NationalAccountsBaseYear                      205 non-null object
# NationalAccountsReferenceYear                 54 non-null object
# SnaPriceValuation                             198 non-null object
# ...

# %%
df_country = pd.DataFrame()
